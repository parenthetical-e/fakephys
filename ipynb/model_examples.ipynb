# %%
from fakephys import model, noise
from bokeh.plotting import figure
from bokeh.io import show, output_notebook
from bokeh.layouts import column, row
output_notebook()

import numpy as np
from scipy.signal import welch
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b08d42ae-a9b1-4cf2-afdc-d777961ec19d">Loading BokehJS ...</span>
#     </div>

# %%
# GLOBAL params
t = 2.5
times = model.create_times(t, 1e-3)

# %% [markdown]
# # Examples
#
# ## Models
#
# Examples timecourses, and parameter sets, for each of the models available to simulate ephys signals.
#
# ### Sin
#
# The obvious inclusion

# %%
X = model.sinwaves(t, 2, f=20, a=1, phase=0)
x = X[0, :]

# -
freqs, psd = welch(x, int(1 / 1e-3), scaling='density', nperseg=1000/2)
m = np.logical_and(freqs > 2, freqs < 100)
freqs = freqs[m]
psd = psd[m]

# -
p1 = figure(plot_width=500, plot_height=250)
p1.line(x=times, y=x, color="black")
p1.xaxis.axis_label = "Time (s)"
p1.yaxis.axis_label = "Activity"

p2 = figure(plot_width=300, plot_height=250)
p2.line(x=freqs, y=psd, color="black")
p2.xaxis.axis_label = "Freq (Hz)"
p2.yaxis.axis_label = "Power (AU)"
show(row(p1, p2))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d1129096-fa34-4bdd-8a84-84cd38337a9a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d1129096-fa34-4bdd-8a84-84cd38337a9a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d1129096-fa34-4bdd-8a84-84cd38337a9a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd1129096-fa34-4bdd-8a84-84cd38337a9a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1180be4a-5038-404f-ba46-438a8b1d2f5f":{"roots":{"references":[{"attributes":{},"id":"f55031c6-ec07-418b-8c62-18c3a7440350","type":"BasicTicker"},{"attributes":{"x":{"field":"x"},"y":{"field":"y"}},"id":"5689e696-c806-493b-9414-48450f91ea6a","type":"Line"},{"attributes":{"plot":{"id":"8402614e-908c-4365-b1d7-58db992eddd9","subtype":"Figure","type":"Plot"}},"id":"feead787-6791-4ff4-9830-466f5824fdf1","type":"HelpTool"},{"attributes":{},"id":"0e520115-a534-4b62-95aa-682f9b6fd06c","type":"BasicTicker"},{"attributes":{"overlay":{"id":"2bcdf321-0694-4649-9a80-c3eb8d50fbd6","type":"BoxAnnotation"},"plot":{"id":"8402614e-908c-4365-b1d7-58db992eddd9","subtype":"Figure","type":"Plot"}},"id":"e651bc33-a7f0-4b2e-949b-8357fff82017","type":"BoxZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ae5f7e22-5ba8-434a-b8b9-cdae9f85a2f5","type":"Line"},{"attributes":{"plot":{"id":"c1a80f81-dd21-469d-b497-32ac8fb47688","subtype":"Figure","type":"Plot"}},"id":"bb16df24-d826-442b-901a-a9be632fdd7e","type":"PanTool"},{"attributes":{},"id":"6425b47f-84c2-4601-afa6-4abbec57fe34","type":"BasicTickFormatter"},{"attributes":{"children":[{"id":"8402614e-908c-4365-b1d7-58db992eddd9","subtype":"Figure","type":"Plot"},{"id":"c1a80f81-dd21-469d-b497-32ac8fb47688","subtype":"Figure","type":"Plot"}]},"id":"bad9b486-ac34-4220-9b65-1a4eeacfdda6","type":"Row"},{"attributes":{"plot":{"id":"c1a80f81-dd21-469d-b497-32ac8fb47688","subtype":"Figure","type":"Plot"},"ticker":{"id":"251aaf90-f0aa-4b37-ad96-f800fe04b45c","type":"BasicTicker"}},"id":"ddab1b55-d02f-4860-8699-78c041cf341c","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"bb16df24-d826-442b-901a-a9be632fdd7e","type":"PanTool"},{"id":"088a5ac4-06af-4210-acd2-ccf2825cc1eb","type":"WheelZoomTool"},{"id":"8c189523-4a08-4afb-a715-858b3d59346b","type":"BoxZoomTool"},{"id":"d8866dc2-f9c6-4a52-8d7a-4812a5a35057","type":"SaveTool"},{"id":"011117e2-65b3-40d5-824c-b31d05fc47ad","type":"ResetTool"},{"id":"41ede49e-3956-4210-9b56-3e5911561774","type":"HelpTool"}]},"id":"aaa40d88-bda7-428d-bb0c-1e89cfa1c2e8","type":"Toolbar"},{"attributes":{"data_source":{"id":"a90a6f3b-1a90-427b-803f-63a2a33904e8","type":"ColumnDataSource"},"glyph":{"id":"5689e696-c806-493b-9414-48450f91ea6a","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ae5f7e22-5ba8-434a-b8b9-cdae9f85a2f5","type":"Line"},"selection_glyph":null},"id":"ad70315f-4271-474f-94b4-ca13eaae24b7","type":"GlyphRenderer"},{"attributes":{},"id":"251aaf90-f0aa-4b37-ad96-f800fe04b45c","type":"BasicTicker"},{"attributes":{"plot":{"id":"8402614e-908c-4365-b1d7-58db992eddd9","subtype":"Figure","type":"Plot"}},"id":"8719e837-c27c-40d8-808a-0f555abd86b4","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2bcdf321-0694-4649-9a80-c3eb8d50fbd6","type":"BoxAnnotation"},{"attributes":{"axis_label":"Power (AU)","formatter":{"id":"b9ba429c-2023-4f20-99e0-fbd674224199","type":"BasicTickFormatter"},"plot":{"id":"c1a80f81-dd21-469d-b497-32ac8fb47688","subtype":"Figure","type":"Plot"},"ticker":{"id":"11197a54-3c03-4e14-a860-cf3546153bc0","type":"BasicTicker"}},"id":"0001b7ac-3919-4b18-9853-88a2f2034f40","type":"LinearAxis"},{"attributes":{},"id":"33398f63-d316-40bb-84aa-10803d370013","type":"BasicTickFormatter"},{"attributes":{},"id":"b9ba429c-2023-4f20-99e0-fbd674224199","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"ac9009cd-b640-46af-967f-93276d1fd6cf","type":"Title"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape": ...

# %%
X.shape
# Out:
# (2, 2500)

# %% [markdown]
# ### A wilson cowan system.
#
# A very simple, but very common way, to capture oscillatory dynamics is in the two-population Wilson-Cowan system.  It features a 'excitatory' population (_E_) and an 'inhibitory' population (_I_), which are coupled to each other and to themselves.  My version of this system features 9 parameters:
#
# 1. P : bias term for E
# 2. Q : bias term for I
# 3. tau_e : the E synaptic time constant (exponential)
# 4. tau_i : the I synaptic time constant (exponential)
# 5. c1 : # connections between E => E (i.e., effective synaptic weight)
# 6. c2 : # connections between I => E
# 7. c3 : # connections between I => I
# 8. c4 : # connections between E => I
# 9. sigma : the standard deviation of [OU](https://en.wikipedia.org/wiki/Ornstein–Uhlenbeck_process) noise added to both populations.
#
# Despite being a mass system (which typically assume many identical neurons, and slow inputs) WC models are quite expressive.
#
# Here are a few examples:

# %% [markdown]
# #### Gamma

# %%
X = model.wc(t, 1, P=4, tau_e=5e-3, tau_i=10e-3, sigma=.01)
x = X[0, :]

# -
freqs, psd = welch(x, int(1 / 1e-3), scaling='density', nperseg=1000/2)
m = np.logical_and(freqs > 2, freqs < 100)
freqs = freqs[m]
psd = psd[m]

# -
p1 = figure(plot_width=500, plot_height=250)
p1.line(x=times, y=x, color="black")
p1.xaxis.axis_label = "Time (s)"
p1.yaxis.axis_label = "Activity"

p2 = figure(plot_width=300, plot_height=250)
p2.line(x=freqs, y=psd, color="black")
p2.xaxis.axis_label = "Freq (Hz)"
p2.yaxis.axis_label = "Power (AU)"
show(row(p1, p2))
# Out:
# INFO       No numerical integration method specified for group 'neurongroup', using method 'euler' (took 0.16s, trying other methods took 0.00s). [brian2.stateupdaters.base.method_choice]
# Starting simulation at t=0. s for a duration of 2.5 s
# 2.5 s (100%) simulated in < 1s
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2845527a-0bf0-4c5a-8180-53bd00102493"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("2845527a-0bf0-4c5a-8180-53bd00102493");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2845527a-0bf0-4c5a-8180-53bd00102493");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2845527a-0bf0-4c5a-8180-53bd00102493' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"536bfd0d-8043-454b-9ba4-a5049a689df0":{"roots":{"references":[{"attributes":{},"id":"3d4c2e42-86b9-4180-b124-42346c1eb726","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8065afaa-b29b-4c32-ac56-1b089045c2e2","type":"Line"},{"attributes":{"axis_label":"Activity","formatter":{"id":"d40c0d6e-ac26-48ab-b452-4ca7e12ae532","type":"BasicTickFormatter"},"plot":{"id":"bbfaf554-7409-490f-8e66-8b423da531fc","subtype":"Figure","type":"Plot"},"ticker":{"id":"3d4c2e42-86b9-4180-b124-42346c1eb726","type":"BasicTicker"}},"id":"028f816f-035d-4881-a6f9-8923ba13022c","type":"LinearAxis"},{"attributes":{"below":[{"id":"5eadc93e-12fe-42c7-9fe7-7c2793c61f5a","type":"LinearAxis"}],"left":[{"id":"028f816f-035d-4881-a6f9-8923ba13022c","type":"LinearAxis"}],"plot_height":250,"plot_width":500,"renderers":[{"id":
type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"9bab57df-c155-4df5-a134-afa2ea6628e8","type":"PanTool"},{"id":"49aa1a4d-58f8-400c-8aea-de44945546e5","type":"WheelZoomTool"},{"id":"70c178e4-6b8f-472a-ab0b-7c09d046573f","type":"BoxZoomTool"},{"id":"93e45da9-ea37-4ce8-959e-4f1cc4f29c03","type":"SaveTool"},{"id":"03d0b33e-1f1e-47cd-863a-f30641ed9377","type":"ResetTool"},{"id":"aac53487-e50a-42c2-9bad-8cbe980b0617","type":"HelpTool"}]},"id":"e29dc640-c680-4931-a4aa-f97b2f51eee9","type":"Toolbar"},{"attributes":{"plot":{"id":"f23da967-06da-478d-b41b-ea8d35d2ebca","subtype":"Figure","type":"Plot"}},"id":"22be04c7-8593-42d2-86a4-d3edf2686866","type":"HelpTool"},{"attributes":{"x":{"field":"x"},"y":{"field":"y"}},"id":"629f640e-5525-4fdc-8b09-e83aa12a25b8","type":"Line"},{"attributes":{},"id":"a209222b-c0b8-4cf2-8b1e-8477393d4d63","type":"BasicTicker"},{"attributes":{},"id":"69b8edda-33c5-4f1a-bbe3-4a269f1c2438","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"63cc5bb1-3e77-4f40-a3d1-9e55a3ae9b30","type":"ColumnDataSource"},"glyph":{"id":"629f640e-5525-4fdc-8b09-e83aa12a25b8","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ac84881b-eea6-4091-a2fc-39b9d9620aaa","type":"Line"},"selection_glyph":null},"id":"b87f99d8-8710-4739-a377-acb6b73139ee","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"66b06521-1e47-4842-ad7a-678dd871ca87","type":"DataRange1d"},{"attributes":{"plot":{"id":"68453f0f-2ff0-49c6-8834-e78dd896c81f","subtype":"Figure","type":"Plot"}},"id":"93e45da9-ea37-4ce8-959e-4f1cc4f29c03","type":"SaveTool"},{"attributes":{},"id":"e187e950-913c-496a-976d-de534a73ad8a","type":"ToolEvents"},{"attributes":{},"id":"4ad5eab0-ed01-4758-a611-f78de83ae368","type":"BasicTicker"},{"attributes":{"overlay":{"id":"7b364206-0cb4-4860-b343-8b99dc9da258","type":"BoxAnnotation"},"plot":{"id":"68453f0f-2ff0-49c6-8834-e78dd896c81f","subtype":"Figure","type":"Plot"}},"id":"70c178e4-6b8f-472a-ab0b-7c09d046573f","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7b364206-0cb4-4860-b343-8b99dc9da258","type":"BoxAnnotation"},{"attributes":{"plot": ...

# %% [markdown]
# #### Unstable oscillations.
#
# All the examples above feature oscillations that are quite stable in time. By inverting the ratio of the time constants on E-I connections, you can produces a dampened oscillation (see first cell below). This type of oscillation has the curious propery of becoming *somewhat* stabilized by introducing a very small amount of noise (see second cell).

# %%
# No noise
X = model.wc(t, 5, P=4, tau_e=40e-3, tau_i=35e-3, sigma=.0)
x = X[0, :]

# -
freqs, psd = welch(x, int(1 / 1e-3), scaling='density', nperseg=1000/2)
m = np.logical_and(freqs > 2, freqs < 100)
freqs = freqs[m]
psd = psd[m]

# -
p1 = figure(plot_width=500, plot_height=250)
p1.line(x=times, y=x, color="black")
p1.xaxis.axis_label = "Time (s)"
p1.yaxis.axis_label = "Activity"

p2 = figure(plot_width=300, plot_height=250)
p2.line(x=freqs, y=psd, color="black")
p2.xaxis.axis_label = "Freq (Hz)"
p2.yaxis.axis_label = "Power (AU)"
show(row(p1, p2))
# Out:
# INFO       No numerical integration method specified for group 'neurongroup_1', using method 'euler' (took 0.16s, trying other methods took 0.00s). [brian2.stateupdaters.base.method_choice]
# Starting simulation at t=0. s for a duration of 2.5 s
# 2.5 s (100%) simulated in < 1s
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="dda49e31-7154-40f7-affa-0e1a789fe7d9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("dda49e31-7154-40f7-affa-0e1a789fe7d9");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("dda49e31-7154-40f7-affa-0e1a789fe7d9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'dda49e31-7154-40f7-affa-0e1a789fe7d9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b9d1f3a3-e5d4-46b8-bf91-8bf0e63b3e77":{"roots":{"references":[{"attributes":{"callback":null},"id":"01010b45-6fcd-453c-b94e-cc27d7997ae0","type":"DataRange1d"},{"attributes":{"plot":{"id":"764c9310-74b3-4e45-b106-01a3143246d6","subtype":"Figure","type":"Plot"}},"id":"03606494-8758-4944-a0aa-b9289e51811b","type":"HelpTool"},{"attributes":{"plot":null,"text":""},"id":
type":"LinearAxis"}],"plot_height":250,"plot_width":300,"renderers":[{"id":"3dfad7e8-23ee-4c8c-86b2-26db35569b4e","type":"LinearAxis"},{"id":"f876d9b0-2660-47ce-8f7f-d88250ab5262","type":"Grid"},{"id":"7b0258c3-3c26-4482-89df-422c36181cfa","type":"LinearAxis"},{"id":"b4ca3041-a384-4d72-91b7-0c0986a3026b","type":"Grid"},{"id":"56092d77-5367-4d30-9aff-cd48479dfd95","type":"BoxAnnotation"},{"id":"2d27e440-a14c-4376-8c62-78cc79d332ba","type":"GlyphRenderer"}],"title":{"id":"1cf7d8db-9e0e-4ca6-bcf4-00b79810b7fa","type":"Title"},"tool_events":{"id":"2b1161cc-ecd3-45d6-9b95-bfb3495ad969","type":"ToolEvents"},"toolbar":{"id":"44876c18-aea5-4b8c-a199-81b2700883ca","type":"Toolbar"},"x_range":{"id":"d0a93d42-034d-4edc-8bef-52a9875bf2ee","type":"DataRange1d"},"y_range":{"id":"88377409-faed-4d0c-9e85-ff073af56a69","type":"DataRange1d"}},"id":"901f5815-6c33-4b5b-9b15-0f39da0b5a7f","subtype":"Figure","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"901f5815-6c33-4b5b-9b15-0f39da0b5a7f","subtype":"Figure","type":"Plot"},"ticker":{"id":"b868d7dc-d2a4-4c4c-b4f6-a30bb6908ac3","type":"BasicTicker"}},"id":"b4ca3041-a384-4d72-91b7-0c0986a3026b","type":"Grid"},{"attributes":{},"id":"4ebc7eae-5c11-47d3-a995-7c2105849e60","type":"BasicTickFormatter"},{"attributes":{"children":[{"id":"819141b0-119b-4ff7-91fc-b2ef8d9f436e","subtype":"Figure","type":"Plot"},{"id":"901f5815-6c33-4b5b-9b15-0f39da0b5a7f","subtype":"Figure","type":"Plot"}]},"id":"b292f427-3b28-4326-a479-de7490352509","type":"Row"},{"attributes":{"plot":{"id":"819141b0-119b-4ff7-91fc-b2ef8d9f436e","subtype":"Figure","type":"Plot"},"ticker":{"id":"6cc9ec1f-21db-4982-b265-10810a2baf77","type":"BasicTicker"}},"id":"76a411d8-8f03-46c5-b454-446b50d637eb","type":"Grid"},{"attributes":{"plot":{"id":"819141b0-119b-4ff7-91fc-b2ef8d9f436e","subtype":"Figure","type":"Plot"}},"id":"cf769d42-d3a5-4575-a369-3d581278c272","type":"ResetTool"},{"attributes":{"plot":{"id":"901f5815-6c33-4b5b-9b15-0f39da0b5a7f","subtype":"Figure","type":"Plot"}},"id":"8e22f580-2d22-4684-829b-baa266863b70","type":"SaveTool"},{"attributes":{"callback":null},"id":"d78c8717-abcb-4288-8d02 ...

# %% [markdown]
# The farther the `tau_e` is from `tau_i` the less stable the oscillation is.

# %%
# Noise, with increased tau_e and decreased tau_i
X = model.wc(t, 5, P=5, tau_e=60e-3, tau_i=20e-3, sigma=.01)
x = X[0, :]

# -
freqs, psd = welch(x, int(1 / 1e-3), scaling='density', nperseg=1000/2)
m = np.logical_and(freqs > 2, freqs < 100)
freqs = freqs[m]
psd = psd[m]

# -
p1 = figure(plot_width=600, plot_height=300)
p1.line(x=times, y=x, color="black")
p1.xaxis.axis_label = "Time (s)"
p1.yaxis.axis_label = "Activity"

p2 = figure(plot_width=300, plot_height=300)
p2.line(x=freqs, y=psd, color="black")
p2.xaxis.axis_label = "Freq (Hz)"
p2.yaxis.axis_label = "Power (AU)"
show(row(p1, p2))
# Out:
# INFO       No numerical integration method specified for group 'neurongroup_1', using method 'euler' (took 0.12s, trying other methods took 0.00s). [brian2.stateupdaters.base.method_choice]
# Starting simulation at t=0. s for a duration of 2.5 s
# 2.5 s (100%) simulated in < 1s
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e9b04d09-5221-475a-b490-37204693abee"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e9b04d09-5221-475a-b490-37204693abee");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e9b04d09-5221-475a-b490-37204693abee");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e9b04d09-5221-475a-b490-37204693abee' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"65da9ff5-3576-4b6e-928e-d50a3361d624":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f
type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[48]},"y":{"__ndarray__":"...","dtype":"float64","shape":[48]}}},"id":"40d43b73-f76f-4265-93e3-ed86fca0bea3","type":"ColumnDataSource"},{"attributes":{},"id":"656a0b6e-f4fb-4ce0-ba85-2e3a9737e319","type":"BasicTickFormat ...

# %% [markdown]
# ### Connectivity
#
# Synapyic time constants are useful in tuning oscillation frequency and stability. To change waveform shape, and oscillatory power, the connections strengths `{c1, c2, c3, c4}` are quite useful.
#
# Let's focus on beta.

# %%
# Set a shorter integration time to see what's going on.
t = 0.5
times = model.create_times(t, 1e-3)

# %%
X = model.wc(t, 1, P=4,  c1=15.0, c2=15.0, c3=15.0, c4=3.0, tau_e=5e-3, tau_i=20e-3, sigma=.01)
x1 = X[0, :]

# -
freqs, psd = welch(x, int(1 / 1e-3), scaling='density', nperseg=1000/2)
m = np.logical_and(freqs > 2, freqs < 100)
freqs = freqs[m]
psd = psd[m]

# -
p1 = figure(plot_width=500, plot_height=250)
p1.line(x=times, y=x, color="black")
p1.xaxis.axis_label = "Time (s)"
p1.yaxis.axis_label = "Activity"

p2 = figure(plot_width=300, plot_height=250)
p2.line(x=freqs, y=psd, color="black")
p2.xaxis.axis_label = "Freq (Hz)"
p2.yaxis.axis_label = "Power (AU)"
show(row(p1, p2))
# Out:
# INFO       No numerical integration method specified for group 'neurongroup', using method 'euler' (took 0.13s, trying other methods took 0.00s). [brian2.stateupdaters.base.method_choice]
# Starting simulation at t=0. s for a duration of 0.5 s
# 0.5 s (100%) simulated in < 1s
# WARNING    /Users/ejp/anaconda/lib/python3.6/site-packages/bokeh/models/sources.py:89: BokehUserWarning: ColumnDataSource's columns must be of the same length
#   lambda: warnings.warn("ColumnDataSource's columns must be of the same length", BokehUserWarning))
#  [py.warnings]

# %% [markdown]
# ### Increase power with c1
#
# - c1 is the connection from E to E. It can act akin to a gain control.

# %%
X = model.wc(t, 1, P=4, c1=18.0, c2=15.0, c3=15.0, c4=3.0, tau_e=5e-3, tau_i=20e-3, sigma=.01)
x2 = X[0, :]

# -
p1 = figure(plot_width=500, plot_height=250)
p1.line(x=times, y=x1, color="black", legend="Baseline")
p1.line(x=times, y=x2, color="red", legend="c1")
p1.xaxis.axis_label = "Time (s)"
p1.yaxis.axis_label = "Activity"
show(p1)

# %%
X = model.wc(t, 1, P=4, c1=10, c2=15.0, c3=15.0, c4=3.0, tau_e=5e-3, tau_i=20e-3, sigma=.01)
x2 = X[0, :]

# -
p1 = figure(plot_width=500, plot_height=250)
p1.line(x=times, y=x1, color="black", legend="Baseline")
p1.line(x=times, y=x2, color="red", legend="c1")
p1.xaxis.axis_label = "Time (s)"
p1.yaxis.axis_label = "Activity"
show(p1)

# %% [markdown]
# - Notice how increasing/decreasing power also alters frequency, and therefore the phase relationship. This illustrates a general property of interdeedence. In a `sinwave` model oscillatory properties are independent. You can change power and leave frequency, or phase intact. This is rarely true in even slightly biological models of oscillation. You can achieve indpendence, but it often requires careful independnce.

# %% [markdown]
# - Going too small with `c1` crosses a critical threshold, and the oscillation is lost. Only fixed point behavoir is observed.

# %%
X = model.wc(t, 1, P=4, c1=3, c2=15.0, c3=15.0, c4=3.0, tau_e=5e-3, tau_i=20e-3, sigma=.0)
x2 = X[0, :]

# -
p1 = figure(plot_width=500, plot_height=250)
p1.line(x=times, y=x1, color="black", legend="Baseline")
p1.line(x=times, y=x2, color="red", legend="c1")
p1.xaxis.axis_label = "Time (s)"
p1.yaxis.axis_label = "Activity"
show(p1)

# %% [markdown]
# ### Changing waveform shape with {c2, c4}
#
# You can alter several aspects of the oscillations shape by altering the connectivity between populations.

# %%
X = model.wc(t, 1, P=4, c1=15.0, c2=40.0, c3=15.0, c4=5.0, tau_e=5e-3, tau_i=20e-3, sigma=.01)
x3 = X[0, :]

# -
p1 = figure(plot_width=500, plot_height=250)
p1.line(x=times, y=x1, color="black", legend="Baseline")
p1.line(x=times, y=x3, color="red", legend="c2")
p1.xaxis.axis_label = "Time (s)"
p1.yaxis.axis_label = "Activity"
show(p1)

# %% [markdown]
# - Notice the much sharper rise, slower decline, as well as the longer duty cycle. (And that the frequency increased, while power declined)

# %% [markdown]
# ## Bias and shape
#
# Increasing the static bias term in the model (`P`) can also alter waveform shape (and the type of oscillator, in a dynamical systems systems sense - limit cycle to a homoclinic orbit).

# %%
X = model.wc(t, 1, P=7, c1=15.0, c2=15.0, c3=15.0, c4=3.0, tau_e=5e-3, tau_i=20e-3, sigma=.01)
x4 = X[0, :]

# -
p1 = figure(plot_width=500, plot_height=250)
p1.line(x=times, y=x1, color="black", legend="Baseline")
p1.line(x=times, y=x4, color="red", legend="P")
p1.xaxis.axis_label = "Time (s)"
p1.yaxis.axis_label = "Activity"
show(p1)

# %% [markdown]
# - But again, `P` is has critical values. Above and below these we get fixed behavoir.

# %%
X = model.wc(t, 1, P=.1, c1=15.0, c2=15.0, c3=15.0, c4=3.0, tau_e=5e-3, tau_i=20e-3, sigma=.0)
x4 = X[0, :]

# -
p1 = figure(plot_width=500, plot_height=250)
p1.line(x=times, y=x1, color="black", legend="Baseline")
p1.line(x=times, y=x4, color="red", legend="P")
p1.xaxis.axis_label = "Time (s)"
p1.yaxis.axis_label = "Activity"
show(p1)

# %%
X = model.wc(t, 1, P=8, c1=15.0, c2=15.0, c3=15.0, c4=3.0, tau_e=5e-3, tau_i=20e-3, sigma=.0)
x4 = X[0, :]

# -
p1 = figure(plot_width=500, plot_height=250)
p1.line(x=times, y=x1, color="black", legend="Baseline")
p1.line(x=times, y=x4, color="red", legend="P")
p1.xaxis.axis_label = "Time (s)"
p1.yaxis.axis_label = "Activity"
show(p1)

# %% [markdown]
# ## The Kuramoto model
#
# The [kuramoto model](https://www.ncbi.nlm.nih.gov/pubmed/21151358) is defined on the unit circle. It has been used for 50 years to study systems of coupled oscillators. It's a great tool to study phase sync between electrodes.
#
# In it's most simlified for, the Kuramoto equation is
#
#     theta_n' = omega_n + (K / N) \sum_{m=1}^{N} sin(theta_m - theta_n) + N(0, sigma)
#
# This version has N paramters:
#
# 1. N : # of oscillators
# 2. omega : the average frequency oscillators in the system
# 3. K : the coupling strength
# 4. sigma: standard deviation of the Gaussian noise term
#
# Where
#
# - `N(0, 1)` is a scalar sample taken from a Gaussian
# - All coupling strengths are equal (i.e. K/ M rather than K_m / N)
# - Coupling is all to all
# - All omegas are the same for each oscillatory
#
# (All three of these latter conditions can be relaxed, if it of interest.)

# %%
# Reset to 2.0 seconds
t = 2
times = model.create_times(t, 1e-3)

# %% [markdown]
# With no noise (`sigma`) and strong coupling (`K`) the model quickly phase-synchornizes.

# %%
K = 6
sigma = 0.01
X = model.kuramoto(t, 10, 10, K, sigma=sigma)

# -
p1 = figure(plot_width=500, plot_height=250)
for i in range(10):
    x = X[i, :]
    p1.line(x=times, y=x, color="black", alpha=0.3)
    p1.xaxis.axis_label = "Time (s)"
    p1.yaxis.axis_label = "Activity"

p2 = figure(plot_width=300, plot_height=250)
for i in range(10):
    x = X[i, :]
    freqs, psd = welch(x, int(1 / 1e-3), scaling='density', nperseg=1000/2)
    m = np.logical_and(freqs > 2, freqs < 100)
    freqs = freqs[m]
    psd = psd[m]

    p2.line(x=freqs, y=psd, color="black")
    p2.xaxis.axis_label = "Freq (Hz)"
    p2.yaxis.axis_label = "Power (AU)"
show(row(p1, p2))

# %% [markdown]
# Adding (a lot) of noise will desynchronize the model.

# %%
K = 6
sigma = 2.5
X = model.kuramoto(t, 10, 10, K, sigma=sigma)

# -
p1 = figure(plot_width=500, plot_height=250)
for i in range(10):
    x = X[i, :]
    p1.line(x=times, y=x, color="black", alpha=0.3)
    p1.xaxis.axis_label = "Time (s)"
    p1.yaxis.axis_label = "Activity"

p2 = figure(plot_width=300, plot_height=250)
for i in range(10):
    x = X[i, :]
    freqs, psd = welch(x, int(1 / 1e-3), scaling='density', nperseg=1000/2)
    m = np.logical_and(freqs > 2, freqs < 100)
    freqs = freqs[m]
    psd = psd[m]

    p2.line(x=freqs, y=psd, color="black")
    p2.xaxis.axis_label = "Freq (Hz)"
    p2.yaxis.axis_label = "Power (AU)"
show(row(p1, p2))

# %% [markdown]
# As will taking `K` sub-critical.

# %%
K = 1
sigma = 0.01
X = model.kuramoto(t, 10, 10, K, sigma=sigma)

# -
p1 = figure(plot_width=500, plot_height=250)
for i in range(10):
    x = X[i, :]
    p1.line(x=times, y=x, color="black", alpha=0.3)
    p1.xaxis.axis_label = "Time (s)"
    p1.yaxis.axis_label = "Activity"

p2 = figure(plot_width=300, plot_height=250)
for i in range(10):
    x = X[i, :]
    freqs, psd = welch(x, int(1 / 1e-3), scaling='density', nperseg=1000/2)
    m = np.logical_and(freqs > 2, freqs < 100)
    freqs = freqs[m]
    psd = psd[m]

    p2.line(x=freqs, y=psd, color="black")
    p2.xaxis.axis_label = "Freq (Hz)"
    p2.yaxis.axis_label = "Power (AU)"
show(row(p1, p2))

# %% [markdown]
# Weakening coupling and adding noise is quite catastrophic

# %%
K = 3
sigma = 2
X = model.kuramoto(t, 10, 10, K, sigma=sigma)

# -
p1 = figure(plot_width=500, plot_height=250)
for i in range(10):
    x = X[i, :]
    p1.line(x=times, y=x, color="black", alpha=0.3)
    p1.xaxis.axis_label = "Time (s)"
    p1.yaxis.axis_label = "Activity"

p2 = figure(plot_width=300, plot_height=250)
for i in range(10):
    x = X[i, :]
    freqs, psd = welch(x, int(1 / 1e-3), scaling='density', nperseg=1000/2)
    m = np.logical_and(freqs > 2, freqs < 100)
    freqs = freqs[m]
    psd = psd[m]

    p2.line(x=freqs, y=psd, color="black")
    p2.xaxis.axis_label = "Freq (Hz)"
    p2.yaxis.axis_label = "Power (AU)"
show(row(p1, p2))

# %% [markdown]
# ## PAC
#
# TODO - Expand the EI model to general PAC. For [example](http://link.springer.com/10.1007/s00422-016-0687-5)

# %% [markdown]
#  ## LIF
#
# TODO -
#
# Create a two-population model of randomly, sparse, connected LIF neurons. Subject this population to osoillatory modulation, recording an estimage of the LFP.

# %% [markdown]
# ## Basal Ganglia
#
# TODO - Gurney produced a mass model of the major BG nuclei. (I've never implemted this, so it may take a bit')
